# %%
import os
import numpy as np
import time
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt


np.random.seed(1234)
tf.random.set_seed(1234)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data() # Load MNIST or FMNIST
assert X_train.shape == (60000, 28, 28)
assert X_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)


# Display randomly selected data
indices = list(np.random.randint(X_train.shape[0],size=3))
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(X_train[indices[i]].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Index {} Class {}".format(indices[i], y_train[indices[i]]))
    plt.tight_layout()

# %% [markdown]
# # Important
# * Always have a validation set, the procedure to create validation or dev set is by performing random sample without replacement on train set and then only using that fraction as dev set.
# * Simple approach is to set some K samples, you can extract them from start, mid or end.
# * Imagine validation set that partially approximates test set distribution and we assume our model would produce identical results when we test it on test set.
# * Always optimize your hyperparameters by looking at performance on validation set and not test set.
# * Do not touch test set, we have this to test how our model would work on unseen data.

# %%
# Split train dataset into train and validation
X_val = X_train[50000:60000]
X_train = X_train[0:50000]
y_val = y_train[50000:60000]
y_train = y_train[0:50000]

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example is", str(X_train.shape[1]), "by", str(X_train.shape[2]))

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example is", str(X_val.shape[1]), "by", str(X_val.shape[2]))

X_train = X_train.reshape(50000, 28*28)
X_val = X_val.reshape(10000, 28*28)
X_test = X_test.reshape(10000, 28*28)

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example has", str(X_train.shape[1]), "features")

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example has", str(X_val.shape[1]), "features")

# Split dataset into batches
#train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(16)
#test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)
# Out:
# size of training set is 50000 samples
# every train example is 28 by 28
# size of validation set is 10000 samples
# every validation example is 28 by 28
# size of training set is 50000 samples
# every train example has 784 features
# size of validation set is 10000 samples
# every validation example has 784 features

# %% [markdown]
# # Points to remember
# * If using any type of neural network, normalize your input between 0-1.
# * One can use various procedures to achieve this, divide by largest value (for images we use 255), subtract mean from data and then normalize, one can even augment them and use other steps for normalization.
# * Normalization is important step, one could observe significant boost in performance just by having better normalization scheme.
# * For targets we always use one-hot encodings.

# %%
#Normalize Data

X_train = X_train/255
X_val = X_val/255
X_test = X_test/255
# X_train[0]
np.max(X_train)
# Out:
# 1.0

# %%
size_input = X_train.shape[1]
size_hidden1 = 128
size_hidden2 = 128
size_hidden3 = 128
size_output = 10

number_of_train_examples = X_train.shape[0]
number_of_test_examples = X_test.shape[0]

y_train = tf.keras.utils.to_categorical(y_train, num_classes=10) # Other function is tf.one_hot(y_train,depth=10)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
print(tf.shape(y_val))
# Out:
# tf.Tensor([10000    10], shape=(2,), dtype=int32)

# %% [markdown]
# # Importance of weight initialization
#
# * One reason backprop based models can perform bettter lies with the weight initialization method, one important point one should remember is that, if yur weights are initialized to be too high or low, backprop would struggle.
# * Hence one should always carefully initialize weights of your model, below i have shown approach with random_normal, one can use random_uniform, truncated version of both, Xavier init and orthogonal.
# * You will find modern day NNs have achieved stable and better performance by simply switching to better init and majority of cases Xavier or Orthogonal works best.
# * Always initialize your bias using zero or some small constant (ideally 0.01 or less works better). We use bias to shift the activation and in some cases it can stabalize learning, but having large bias can cause negative results.
#
# # Loss function
#
# * We will always cross-entropy loss for classification.
#
# * tf softmax,
# loss= tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf)), this function is simply saying that it will calculate softmax for you, simply provide logits to it.
#
# * In other output of your forward pass directly goes this function. Now this operator will calculate or apply softmax over prediction or logits and calculate cross-entropy between prediction and target. I am using reduce_mean since we apply this over batches.
# * Second is using keras
# Method 1 :- This function requires logits, hence same as above you will pass logits or output variable to this function. Now remember you need from_logits = True, for this to work.
# cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
# loss_x = cce(y_true_tf, y_pred_tf)
#
# * Method 2:- In this we will apply softmax to output function and then pass to CCE loss.
# So the approach is
# output = tf.nn.softmax(output)
# cce = tf.keras.losses.CategoricalCrossentropy(from_logits=False)
# loss_x = cce(y_true_tf, y_pred_tf)

# %%
# Define class to build mlp model
class MLP(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device

    # init timetep and momemt vars
    self.iter = 0
    self.m = {}; self.v = {}; self.u = {}
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]
  
 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def resetMoments(self):
   self.iter = 0
   self.m = {}; self.v = {}; self.u = {}
   nlayers = int(len(self.variables)/2)

   self.m['tick'] = 0; self.v['tick'] = 0; self.u['tick'] = 0 
   for l in range(nlayers):
     self.m['dW' + str(l+1)] = np.zeros((self.variables[l]).shape)
     self.m['db' + str(l+1)] = np.zeros((self.variables[l+nlayers]).shape)
     
     self.v['dW' + str(l+1)] = np.zeros((self.variables[l]).shape)
     self.v['db' + str(l+1)] = np.zeros((self.variables[l+nlayers]).shape)

     self.u['dW' + str(l+1)] = np.zeros((self.variables[l]).shape)
     self.u['db' + str(l+1)] = np.zeros((self.variables[l+nlayers]).shape)

 def initOptParams(self, vars, grads):
   '''
   Set up params for optimizer routine
   '''
   nvars = len(vars)
   nlayers = int(nvars/2)
   params = {}; gradsDict = {}

   for i in range(nlayers):
     params['W'+str(i+1)] = vars[i].numpy()
     params['b'+str(i+1)] = vars[i+nlayers].numpy()     
     gradsDict['dW'+str(i+1)] = grads[i].numpy()
     gradsDict['db'+str(i+1)] = grads[i+nlayers].numpy()

   m = self.m; v =self.v; u = self.u

   return m, v, u, params, gradsDict


 def unpackParams(self, params):
   '''
   Unpack params from dict and update opt variables
   '''
   nlayers = int(len(self.variables)/2)

   for i in range(nlayers):
     self.variables[i].assign( tf.convert_to_tensor(params['W'+str(i+1)]) )
     self.variables[i+nlayers].assign( tf.convert_to_tensor(params['b'+str(i+1)]) ) 
   

 def customOptimizer(self, grads, vars, step=1e-3, beta1=0.9, beta2=0.999, beta3=0.999987):
   '''
   Custom optimzer implementation 
   ''' 
   # init moments, eps
   m, v, u, params, gradsDict = self.initOptParams(vars, grads)
   eps = 1e-8

   mHat = {}; vHat = {}; uHat = {}
   nlayers = int(len(vars)/2)
   
   # current time step 
   t = self.iter
    
   for l in range(nlayers):
    # update moments and correct them
    m["dW" + str(l+1)] = beta1 * m["dW" + str(l+1)] + (1 - beta1) * gradsDict["dW" + str(l+1)]
    m["db" + str(l+1)] = beta1 * m["db" + str(l+1)] + (1 - beta1) * gradsDict["db" + str(l+1)]
    mHat["dW" + str(l+1)] = m["dW" + str(l+1)] /(1 - beta1 ** t)
    mHat["db" + str(l+1)] = m["db" + str(l+1)] /(1 - beta1 ** t)

    v["dW" + str(l+1)] = beta2 * v["dW" + str(l+1)] + (1 - beta2) * np.square( gradsDict["dW" + str(l+1)] ) 
    v["db" + str(l+1)] = beta2 * v["db" + str(l+1)] + (1 - beta2) * np.square( gradsDict["db" + str(l+1)] ) 
    vHat["dW" + str(l+1)] = v["dW" + str(l+1)] /(1 - beta2 ** t)
    vHat["db" + str(l+1)] = v["db" + str(l+1)] /(1 - beta2 ** t)

    u["dW" + str(l+1)] = beta3 * u["dW" + str(l+1)] + (1 - beta3) * np.power( gradsDict["dW" + str(l+1)], 3 ) 
    u["db" + str(l+1)] = beta3 * u["db" + str(l+1)] + (1 - beta3) * np.power( gradsDict["db" + str(l+1)], 3 ) 
    uHat["dW" + str(l+1)] = u["dW" + str(l+1)] /(1 - beta3 ** t)
    uHat["db" + str(l+1)] = u["db" + str(l+1)] /(1 - beta3 ** t)

    # update params
    WDenominator = eps +( np.sqrt(np.abs(vHat['dW'+str(l+1)])) + np.power(np.abs(uHat['dW'+str(l+1)]), 1./3)*eps )
    bDenominator = eps +( np.sqrt(np.abs(vHat['db'+str(l+1)])) + np.power(np.abs(uHat['db'+str(l+1)]), 1./3)*eps )
    params['W'+str(l+1)] -= step*mHat['dW'+str(l+1)]/WDenominator
    params['b'+str(l+1)] -= step*mHat['db'+str(l+1)]/bDenominator

   # update ticks for checks of updation
   m['tick'] += 1; v['tick'] += 1; u['tick'] += 1
   self.unpackParams(params)


 def backward(self, X_train, y_train):
    """
    backward pass
    """
    # SGD
    # optimizer = tf.keras.optimizers.SGD(learning_rate = 0.1)

    # RMSProp
    # optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)

    # Adam
    # optimizer = tf.keras.optimizers.Adam(
      # learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
    
    with tf.GradientTape() as tape:    
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
    
    grads = tape.gradient(current_loss, self.variables)

    self.customOptimizer(grads, self.variables)
    # optimizer.apply_gradients(zip(grads, self.variables))

    # check ticks for testing sanity of moment updation
    # print("Moment ticks (m, v, u): ", self.m['tick'], self.v['tick'], self.u['tick'])
           
 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

#  def stderr(self,y_pred):
#     """
#      Calculate standard error
#      """
#     y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
#     std_dev = np.std(y_pred_tf) #Calculates standard deviation
#     std_err = std_dev/sqrt(len(y_pred_tf))
#     return std_err 


#  def var(self,y_pred):
#     """
#      Calculate variance 
#      """
#     y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
#     std_dev = np.std(y_pred_tf) #Calculates standard deviation
#     variance = (std_dev**2) # calculate variance
#     return variance

# %%
import math
import os

OPTIMIZER = 'CustomOptimizer'

# Set number of epochs
NUM_EPOCHS = 10

# Do 10 runs , changing rand seed each time
for nrun in range(10):
  randSeed = int(math.modf(time.time())[0]*1e5)
  print("Run - " + str(nrun+1) + " seed - " + str(randSeed) + "\n")
  # setup logfile for run
  filename = OPTIMIZER+'_'+str(nrun+1)+'_FashionMNIST'+'.txt'
  logFile = open(filename, 'w')

  # Initialize model using CPU
  mlp_on_cpu = MLP(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

  time_start = time.time()

  # For each epoch do->
  for epoch in range(NUM_EPOCHS):
    loss_total = tf.zeros([1,1], dtype=tf.float32)
    lt = 0
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(1234)).batch(128)
    kz = 0
    mlp_on_cpu.resetMoments()
    accuracy_z = 0.0
    cur_train_acc = 0.0
    # For each mini-batch do ->
    for inputs, outputs in train_ds:
      qw, tr = tf.shape(inputs)
      kz = kz + 1
      preds = mlp_on_cpu.forward(inputs) 
      loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
      lt = lt + mlp_on_cpu.loss(preds, outputs)
      mlp_on_cpu.iter += 1
      mlp_on_cpu.backward(inputs, outputs)

    preds = mlp_on_cpu.forward(X_train)
    # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
    preds = tf.nn.softmax(preds)
    correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
    accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_train_acc += accuracy_z.numpy()
    ds = cur_train_acc

    print('\nTrain Accuracy: {:.4f}'.format(ds))
    logFile.write('\nTrain Accuracy: {:.4f}'.format(ds))
    print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
    logFile.write('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))

    preds_val = mlp_on_cpu.forward(X_val)
    preds_val = tf.nn.softmax(preds_val)
    correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_val_acc = accuracy.numpy()

    print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
    logFile.write('\nValidation Accuracy: {:.4f}\n'.format(cur_val_acc))
    
    plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

          
  time_taken = time.time() - time_start
    
  # Validate model
    
  print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
  logFile.write('\nTotal time taken (in seconds): {:.2f}\n'.format(time_taken))
  #For per epoch_time = Total_Time / Number_of_epochs

  # One step inference ->
  test_loss_total = tf.Variable(0, dtype=tf.float32)
  correct_prediction = tf.Variable(0, dtype=tf.float32)

  test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)

  #test_loss_total = 0.0
  for inputs, outputs in test_ds:
    preds = mlp_on_cpu.forward(inputs)
    test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
  print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))
  logFile.write('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

  # Test model
  preds_test = mlp_on_cpu.forward(X_test)
  preds_test = tf.nn.softmax(preds_test)
  correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_test_acc = accuracy.numpy()
  print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
  logFile.write('\nTest Accuracy: {:.2f}'.format(cur_test_acc))

  logFile.close()
# Out:
# Run - 1 seed - 99798
#
#
# Train Accuracy: 0.8574
# Number of Epoch = 1 - Average Cross Entropy:= 0.004260947265625
#
# Validation Accuracy: 0.8466
#
# Train Accuracy: 0.8744
# Number of Epoch = 2 - Average Cross Entropy:= 0.003001890869140625
#
# Validation Accuracy: 0.8585
#
# Train Accuracy: 0.8780
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026603665161132814
#
# Validation Accuracy: 0.8590
#
# Train Accuracy: 0.8882
# Number of Epoch = 4 - Average Cross Entropy:= 0.0024478654479980467
#
# Validation Accuracy: 0.8667
#
# Train Accuracy: 0.8973
# Number of Epoch = 5 - Average Cross Entropy:= 0.002272821502685547
#
# Validation Accuracy: 0.8708
#
# Train Accuracy: 0.9025
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021228038024902343
#
# Validation Accuracy: 0.8761
#
# Train Accuracy: 0.9113
# Number of Epoch = 7 - Average Cross Entropy:= 0.001995033264160156
#
# Validation Accuracy: 0.8813
#
# Train Accuracy: 0.9155
# Number of Epoch = 8 - Average Cross Entropy:= 0.001898811798095703
#
# Validation Accuracy: 0.8826
#
# Train Accuracy: 0.9141
# Number of Epoch = 9 - Average Cross Entropy:= 0.0017943794250488282
#
# Validation Accuracy: 0.8788
#
# Train Accuracy: 0.9160
# Number of Epoch = 10 - Average Cross Entropy:= 0.001715047149658203
#
# Validation Accuracy: 0.8793
#
# Total time taken (in seconds): 196.18
# Test loss: 0.0945
#
# Test Accuracy: 0.87
# Run - 2 seed - 12032
#
#
# Train Accuracy: 0.8585
# Number of Epoch = 1 - Average Cross Entropy:= 0.004377572021484375
#
# Validation Accuracy: 0.8493
#
# Train Accuracy: 0.8725
# Number of Epoch = 2 - Average Cross Entropy:= 0.003023487548828125
#
# Validation Accuracy: 0.8582
#
# Train Accuracy: 0.8761
# Number of Epoch = 3 - Average Cross Entropy:= 0.002665870666503906
#
# Validation Accuracy: 0.8603
#
# Train Accuracy: 0.8881
# Number of Epoch = 4 - Average Cross Entropy:= 0.002447670440673828
#
# Validation Accuracy: 0.8664
#
# Train Accuracy: 0.8944
# Number of Epoch = 5 - Average Cross Entropy:= 0.0022890220642089844
#
# Validation Accuracy: 0.8695
#
# Train Accuracy: 0.9019
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021607623291015625
#
# Validation Accuracy: 0.8757
#
# Train Accuracy: 0.9068
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020424429321289064
#
# Validation Accuracy: 0.8819
#
# Train Accuracy: 0.9115
# Number of Epoch = 8 - Average Cross Entropy:= 0.001928618927001953
#
# Validation Accuracy: 0.8842
#
# Train Accuracy: 0.9137
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018355125427246095
#
# Validation Accuracy: 0.8828
#
# Train Accuracy: 0.9156
# Number of Epoch = 10 - Average Cross Entropy:= 0.001766999053955078
#
# Validation Accuracy: 0.8848
#
# Total time taken (in seconds): 178.97
# Test loss: 0.0900
#
# Test Accuracy: 0.88
# Run - 3 seed - 98
#
#
# Train Accuracy: 0.8590
# Number of Epoch = 1 - Average Cross Entropy:= 0.004461316223144531
#
# Validation Accuracy: 0.8495
#
# Train Accuracy: 0.8740
# Number of Epoch = 2 - Average Cross Entropy:= 0.0030471630859375
#
# Validation Accuracy: 0.8603
#
# Train Accuracy: 0.8764
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026880563354492186
#
# Validation Accuracy: 0.8603
#
# Train Accuracy: 0.8934
# Number of Epoch = 4 - Average Cross Entropy:= 0.002463087310791016
#
# Validation Accuracy: 0.8743
#
# Train Accuracy: 0.8946
# Number of Epoch = 5 - Average Cross Entropy:= 0.0022811294555664064
#
# Validation Accuracy: 0.8721
#
# Train Accuracy: 0.9005
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021460551452636718
#
# Validation Accuracy: 0.8759
#
# Train Accuracy: 0.9107
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020355140686035156
#
# Validation Accuracy: 0.8849
#
# Train Accuracy: 0.9047
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019269480895996094
#
# Validation Accuracy: 0.8764
#
# Train Accuracy: 0.9143
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018213002014160157
#
# Validation Accuracy: 0.8826
#
# Train Accuracy: 0.9150
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017418115234375
#
# Validation Accuracy: 0.8801
#
# Total time taken (in seconds): 175.69
# Test loss: 0.0936
#
# Test Accuracy: 0.87
# Run - 4 seed - 53252
#
#
# Train Accuracy: 0.8578
# Number of Epoch = 1 - Average Cross Entropy:= 0.004350926818847656
#
# Validation Accuracy: 0.8500
#
# Train Accuracy: 0.8735
# Number of Epoch = 2 - Average Cross Entropy:= 0.0030278164672851563
#
# Validation Accuracy: 0.8607
#
# Train Accuracy: 0.8830
# Number of Epoch = 3 - Average Cross Entropy:= 0.002684068603515625
#
# Validation Accuracy: 0.8674
#
# Train Accuracy: 0.8881
# Number of Epoch = 4 - Average Cross Entropy:= 0.0024684426879882813
#
# Validation Accuracy: 0.8694
#
# Train Accuracy: 0.8916
# Number of Epoch = 5 - Average Cross Entropy:= 0.0022929417419433593
#
# Validation Accuracy: 0.8713
#
# Train Accuracy: 0.8991
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021578314208984374
#
# Validation Accuracy: 0.8760
#
# Train Accuracy: 0.8997
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020360397338867187
#
# Validation Accuracy: 0.8759
#
# Train Accuracy: 0.9000
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019303575134277343
#
# Validation Accuracy: 0.8749
#
# Train Accuracy: 0.9090
# Number of Epoch = 9 - Average Cross Entropy:= 0.001844439697265625
#
# Validation Accuracy: 0.8771
#
# Train Accuracy: 0.9126
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017565950012207031
#
# Validation Accuracy: 0.8815
#
# Total time taken (in seconds): 175.26
# Test loss: 0.0933
#
# Test Accuracy: 0.87
# Run - 5 seed - 67280
#
#
# Train Accuracy: 0.8571
# Number of Epoch = 1 - Average Cross Entropy:= 0.004369342651367188
#
# Validation Accuracy: 0.8479
#
# Train Accuracy: 0.8750
# Number of Epoch = 2 - Average Cross Entropy:= 0.003049071350097656
#
# Validation Accuracy: 0.8627
#
# Train Accuracy: 0.8841
# Number of Epoch = 3 - Average Cross Entropy:= 0.002704534912109375
#
# Validation Accuracy: 0.8694
#
# Train Accuracy: 0.8888
# Number of Epoch = 4 - Average Cross Entropy:= 0.0024747109985351562
#
# Validation Accuracy: 0.8702
#
# Train Accuracy: 0.8936
# Number of Epoch = 5 - Average Cross Entropy:= 0.0023064834594726563
#
# Validation Accuracy: 0.8737
#
# Train Accuracy: 0.9039
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021795306396484374
#
# Validation Accuracy: 0.8782
#
# Train Accuracy: 0.9020
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020540568542480467
#
# Validation Accuracy: 0.8753
#
# Train Accuracy: 0.9021
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019366218566894532
#
# Validation Accuracy: 0.8719
#
# Train Accuracy: 0.9097
# Number of Epoch = 9 - Average Cross Entropy:= 0.001837104949951172
#
# Validation Accuracy: 0.8799
#
# Train Accuracy: 0.9089
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017661372375488281
#
# Validation Accuracy: 0.8769
#
# Total time taken (in seconds): 174.67
# Test loss: 0.0969
#
# Test Accuracy: 0.87
# Run - 6 seed - 4626
#
#
# Train Accuracy: 0.8604
# Number of Epoch = 1 - Average Cross Entropy:= 0.0043286135864257815
#
# Validation Accuracy: 0.8484
#
# Train Accuracy: 0.8715
# Number of Epoch = 2 - Average Cross Entropy:= 0.0030216131591796875
#
# Validation Accuracy: 0.8588
#
# Train Accuracy: 0.8843
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026720382690429687
#
# Validation Accuracy: 0.8675
#
# Train Accuracy: 0.8892
# Number of Epoch = 4 - Average Cross Entropy:= 0.00246316162109375
#
# Validation Accuracy: 0.8718
#
# Train Accuracy: 0.8985
# Number of Epoch = 5 - Average Cross Entropy:= 0.0023013848876953123
#
# Validation Accuracy: 0.8773
#
# Train Accuracy: 0.9028
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021627621459960936
#
# Validation Accuracy: 0.8790
#
# Train Accuracy: 0.9092
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020386102294921876
#
# Validation Accuracy: 0.8839
#
# Train Accuracy: 0.9063
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019341014099121094
#
# Validation Accuracy: 0.8789
#
# Train Accuracy: 0.9101
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018256886291503906
#
# Validation Accuracy: 0.8809
#
# Train Accuracy: 0.9158
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017461044311523437
#
# Validation Accuracy: 0.8826
#
# Total time taken (in seconds): 175.66
# Test loss: 0.0922
#
# Test Accuracy: 0.88
# Run - 7 seed - 43032
#
#
# Train Accuracy: 0.8593
# Number of Epoch = 1 - Average Cross Entropy:= 0.004320765380859375
#
# Validation Accuracy: 0.8507
#
# Train Accuracy: 0.8752
# Number of Epoch = 2 - Average Cross Entropy:= 0.0030235797119140626
#
# Validation Accuracy: 0.8575
#
# Train Accuracy: 0.8824
# Number of Epoch = 3 - Average Cross Entropy:= 0.002659447326660156
#
# Validation Accuracy: 0.8628
#
# Train Accuracy: 0.8893
# Number of Epoch = 4 - Average Cross Entropy:= 0.0024484161376953123
#
# Validation Accuracy: 0.8691
#
# Train Accuracy: 0.8969
# Number of Epoch = 5 - Average Cross Entropy:= 0.002268077087402344
#
# Validation Accuracy: 0.8721
#
# Train Accuracy: 0.8998
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021362109375
#
# Validation Accuracy: 0.8749
#
# Train Accuracy: 0.9067
# Number of Epoch = 7 - Average Cross Entropy:= 0.002020390625
#
# Validation Accuracy: 0.8796
#
# Train Accuracy: 0.9115
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019173193359375
#
# Validation Accuracy: 0.8818
#
# Train Accuracy: 0.9106
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018465264892578125
#
# Validation Accuracy: 0.8802
#
# Train Accuracy: 0.9145
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017432066345214844
#
# Validation Accuracy: 0.8788
#
# Total time taken (in seconds): 178.25
# Test loss: 0.0925
#
# Test Accuracy: 0.87
# Run - 8 seed - 33606
#
#
# Train Accuracy: 0.8530
# Number of Epoch = 1 - Average Cross Entropy:= 0.004444049682617188
#
# Validation Accuracy: 0.8424
#
# Train Accuracy: 0.8741
# Number of Epoch = 2 - Average Cross Entropy:= 0.003050034484863281
#
# Validation Accuracy: 0.8585
#
# Train Accuracy: 0.8840
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026848593139648437
#
# Validation Accuracy: 0.8664
#
# Train Accuracy: 0.8906
# Number of Epoch = 4 - Average Cross Entropy:= 0.002454070739746094
#
# Validation Accuracy: 0.8705
#
# Train Accuracy: 0.8985
# Number of Epoch = 5 - Average Cross Entropy:= 0.0022999774169921877
#
# Validation Accuracy: 0.8779
#
# Train Accuracy: 0.8991
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021584536743164064
#
# Validation Accuracy: 0.8761
#
# Train Accuracy: 0.9054
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020379579162597655
#
# Validation Accuracy: 0.8799
#
# Train Accuracy: 0.9081
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019370817565917968
#
# Validation Accuracy: 0.8808
#
# Train Accuracy: 0.9105
# Number of Epoch = 9 - Average Cross Entropy:= 0.00184178466796875
#
# Validation Accuracy: 0.8800
#
# Train Accuracy: 0.9137
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017882510375976564
#
# Validation Accuracy: 0.8805
#
# Total time taken (in seconds): 175.27
# Test loss: 0.0935
#
# Test Accuracy: 0.87
# Run - 9 seed - 9686
#
#
# Train Accuracy: 0.8601
# Number of Epoch = 1 - Average Cross Entropy:= 0.004274208374023438
#
# Validation Accuracy: 0.8503
#
# Train Accuracy: 0.8746
# Number of Epoch = 2 - Average Cross Entropy:= 0.003000660095214844
#
# Validation Accuracy: 0.8608
#
# Train Accuracy: 0.8876
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026603179931640624
#
# Validation Accuracy: 0.8714
#
# Train Accuracy: 0.8922
# Number of Epoch = 4 - Average Cross Entropy:= 0.002441065673828125
#
# Validation Accuracy: 0.8734
#
# Train Accuracy: 0.9005
# Number of Epoch = 5 - Average Cross Entropy:= 0.002281537322998047
#
# Validation Accuracy: 0.8799
#
# Train Accuracy: 0.8965
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021423806762695314
#
# Validation Accuracy: 0.8732
#
# Train Accuracy: 0.8996
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020277561950683594
#
# Validation Accuracy: 0.8725
#
# Train Accuracy: 0.9024
# Number of Epoch = 8 - Average Cross Entropy:= 0.001919053497314453
#
# Validation Accuracy: 0.8758
#
# Train Accuracy: 0.9116
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018123928833007812
#
# Validation Accuracy: 0.8799
#
# Train Accuracy: 0.9090
# Number of Epoch = 10 - Average Cross Entropy:= 0.0017274668884277344
#
# Validation Accuracy: 0.8765
#
# Total time taken (in seconds): 176.30
# Test loss: 0.0983
#
# Test Accuracy: 0.87
# Run - 10 seed - 8099
#
#
# Train Accuracy: 0.8597
# Number of Epoch = 1 - Average Cross Entropy:= 0.004306431884765625
#
# Validation Accuracy: 0.8503
#
# Train Accuracy: 0.8781
# Number of Epoch = 2 - Average Cross Entropy:= 0.003029552001953125
#
# Validation Accuracy: 0.8660
#
# Train Accuracy: 0.8835
# Number of Epoch = 3 - Average Cross Entropy:= 0.0026857766723632813
#
# Validation Accuracy: 0.8678
#
# Train Accuracy: 0.8851
# Number of Epoch = 4 - Average Cross Entropy:= 0.002476302490234375
#
# Validation Accuracy: 0.8664
#
# Train Accuracy: 0.8958
# Number of Epoch = 5 - Average Cross Entropy:= 0.002299016571044922
#
# Validation Accuracy: 0.8744
#
# Train Accuracy: 0.8988
# Number of Epoch = 6 - Average Cross Entropy:= 0.0021441368103027342
#
# Validation Accuracy: 0.8726
#
# Train Accuracy: 0.9058
# Number of Epoch = 7 - Average Cross Entropy:= 0.0020367091369628905
#
# Validation Accuracy: 0.8777
#
# Train Accuracy: 0.9102
# Number of Epoch = 8 - Average Cross Entropy:= 0.001930283203125
#
# Validation Accuracy: 0.8807
#
# Train Accuracy: 0.9117
# Number of Epoch = 9 - Average Cross Entropy:= 0.001846370849609375
#
# Validation Accuracy: 0.8793
#
# Train Accuracy: 0.9144
# Number of Epoch = 10 - Average Cross Entropy:= 0.001775092010498047
#
# Validation Accuracy: 0.8803
#
# Total time taken (in seconds): 173.69
# Test loss: 0.0933
#
# Test Accuracy: 0.88

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
